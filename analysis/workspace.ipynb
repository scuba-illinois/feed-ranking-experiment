# %%
import pandas as pd
import numpy as np
import random
from uuid import uuid4
import bambi as bmb
import arviz as az
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
def create_snapshots():
    snapshots = {}

    for i in range(5):
        posts = {j + 1: str(uuid4()) for j in range(10)}
        snapshots[str(uuid4())] = posts
    return snapshots


snapshots = create_snapshots()

# %%
def rotate_list_randomly(lst):
    if not lst:
        return lst
    n = len(lst)

    # Choose random number of rotations between 1 and n-1
    k = random.randint(1, n - 1)

    # Randomly decide direction: True for right, False for left
    right = random.choice([True, False])

    if right:
        rotated = lst[-k:] + lst[:-k]  # Rotate right
    else:
        rotated = lst[k:] + lst[:k]  # Rotate left

    return rotated


def fake_participant_data(snapshots=snapshots):

    participant_id = str(uuid4())

    # Which snapshots are they looking at?
    selected_snapshots = random.sample(list(snapshots.keys()), k=3)

    shown_proof = random.choice([True, False])

    # Pull out num_selected posts, with lower indices more likely.
    weights = (
        np.linspace(5, 1, 10) if shown_proof else np.linspace(10, 1, 10)
    )  # Higher weight for lower indices
    weights /= weights.sum()  # Normalize to sum to 1

    selections = []
    ratings = []

    for snapshot in selected_snapshots:

        # Get the posts in the correct order.
        posts = [snapshots[snapshot][i + 1] for i in range(10)]

        # Rotate the posts in this snapshot.
        posts = rotate_list_randomly(posts)

        # How many posts did they select?
        num_selected = random.choice([1, 2, 3])

        selected_indices = np.random.choice(
            range(10), size=num_selected, replace=False, p=weights
        )

        selections += [
            {
                "participant_id": participant_id,
                "rank": int(i) + 1,
                "snapshot_id": snapshot,
                "post_id": posts[int(i)],
                "shown_proof": shown_proof,
                "selected": True,
            }
            for i in selected_indices
        ]

        selections += [
            {
                "participant_id": participant_id,
                "rank": int(i) + 1,
                "snapshot_id": snapshot,
                "post_id": posts[int(i)],
                "shown_proof": shown_proof,
                "selected": False,
            }
            for i in range(10)
            if i not in selected_indices
        ]

    selections_df = pd.DataFrame(selections).set_index(["snapshot_id", "post_id"])

    for snapshot in selected_snapshots:

        # Get the selected post IDs.
        selected_posts = (
            selections_df.query("snapshot_id == @snapshot and selected == True")
            .reset_index()["post_id"]
            .values.tolist()
        )

        # Get the unselected post IDs.
        unselected_posts = (
            selections_df.query("snapshot_id == @snapshot and selected == False")
            .sample(3)
            .reset_index()["post_id"]
            .values.tolist()
        )

        for post in selected_posts:
            for perception in ["relevance", "trustworthiness", "content_quality"]:
                ratings.append(
                    {
                        "participant_id": participant_id,
                        "snapshot_id": snapshot,
                        "post_id": post,
                        "selected": True,
                        "rank": int(
                            selections_df.query(
                                "snapshot_id == @snapshot and post_id == @post"
                            )["rank"].values[0]
                        ),
                        "shown_proof": shown_proof,
                        "perception": perception,
                        "rating": max(
                            round(
                                random.randint(1, 5)
                                + (0 if shown_proof and random.random() > 0.2 else 1)
                                + 2
                            ),
                            5,
                        ),
                    }
                )

        for post in unselected_posts:
            for perception in ["relevance", "trustworthiness", "content_quality"]:
                ratings.append(
                    {
                        "participant_id": participant_id,
                        "snapshot_id": snapshot,
                        "post_id": post,
                        "selected": False,
                        "rank": int(
                            selections_df.query(
                                "snapshot_id == @snapshot and post_id == @post"
                            )["rank"].values[0]
                        ),
                        "shown_proof": shown_proof,
                        "perception": perception,
                        "rating": random.randint(1, 5),
                    }
                )

    return selections, ratings


selections, ratings = fake_participant_data()

# %%
num_participants = 200

selections, ratings = [], []

for _ in tqdm(range(num_participants)):

    _selections, _ratings = fake_participant_data()
    selections += _selections
    ratings += _ratings

selections_df = pd.DataFrame(selections).set_index(["snapshot_id", "post_id"])
ratings_df = pd.DataFrame(ratings).set_index(["snapshot_id", "post_id"])
# Out:
# 100%|██████████| 200/200 [00:04<00:00, 44.63it/s]

# %%
# How many participants saw each snapshot?
selections_df.groupby("snapshot_id")["participant_id"].nunique()
# Out:
# snapshot_id
# 1f725867-0718-4c2a-bc17-dc73e6cf43c3    121
# 4fdb2d83-54cc-4fbf-85bb-49b02d7bcc71    125
# 67d63ec7-78e6-4d8f-8101-8469ac1f9e00    119
# ba7adffb-c71b-4959-b642-3fa6cb47245a    116
# df4c1747-cfae-4ee0-81e0-a32c6ca83d5a    119
# Name: participant_id, dtype: int64

# %%
selections_df.query("selected").groupby("rank").size()
# Out:
# rank
# 1     229
# 2     196
# 3     158
# 4     132
# 5     117
# 6     119
# 7      95
# 8      68
# 9      72
# 10     32
# dtype: int64

# %% [markdown]
# ---
#
# ## H2 selection modeling, because it's easier.

# %%
h2_model = bmb.Model(
    formula="selected ~ shown_proof * C(rank) + (1 | participant_id) + (1 | snapshot_id) + (1 | post_id)",
    data=selections_df.reset_index(),
    family="bernoulli",
)

h2_results = h2_model.fit(target_accept=0.99)
# Out:
# Modeling the probability that selected==1
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Intercept, shown_proof, C(rank), shown_proof:C(rank), 1|participant_id_sigma, 1|participant_id_offset, 1|snapshot_id_sigma, 1|snapshot_id_offset, 1|post_id_sigma, 1|post_id_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 43 seconds.

# %%
np.exp(0.11)
# Out:
# np.float64(1.1162780704588713)

# %%
az.summary(h2_results).head(30)
# Out:
#                                                      mean     sd  hdi_3%  \
# Intercept                                          -0.672  0.128  -0.907
# shown_proof                                        -0.053  0.172  -0.388
# C(rank)[2]                                          0.110  0.174  -0.216
# C(rank)[3]                                         -0.089  0.178  -0.423
# C(rank)[4]                                         -0.451  0.183  -0.805
# C(rank)[5]                                         -0.505  0.184  -0.856
# C(rank)[6]                                         -0.900  0.198  -1.265
# C(rank)[7]                                         -1.054  0.206  -1.428
# C(rank)[8]                                         -1.391  0.224  -1.799
# C(rank)[9]                                         -1.747  0.243  -2.177
# C(rank)[10]                                        -2.599  0.335  -3.268
# shown_proof:C(rank)[2]                             -0.497  0.248  -0.943
# shown_proof:C(rank)[3]                             -0.097  0.250  -0.561
# shown_proof:C(rank)[4]                              0.070  0.250  -0.394
# shown_proof:C(rank)[5]                              0.053  0.252  -0.409
# shown_proof:C(rank)[6]                              0.089  0.272  -0.423
# shown_proof:C(rank)[7]                              0.112  0.284  -0.410
# shown_proof:C(rank)[8]                              0.394  0.295  -0.150
# shown_proof:C(rank)[9]                              0.049  0.333  -0.562
# shown_proof:C(rank)[10]                             0.753  0.422   0.003
# 1|participant_id_sigma                              0.035  0.027   0.000
# 1|snapshot_id_sigma                                 0.056  0.062   0.000
# 1|post_id_sigma                                     0.098  0.055   0.001
# 1|participant_id[0121c5f9-d668-4f03-802a-5b1c84...  0.003  0.045  -0.094
# 1|participant_id[024cc19c-833b-484f-b242-3c5393...  0.000  0.044  -0.093
# 1|participant_id[0292643c-984a-4dd9-9635-791955... -0.002  0.042  -0.084
# 1|participant_id[03255d3f-25b0-43f3-849a-54b927...  0.001  0.044  -0.087
# 1|participant_id[03717b3e-2012-4b39-be0f-e97e92...  0.004  0.045  -0.092
# 1|participant_id[09bac91e-de8b-42df-bb9f-b5d19c...  0.001  0.045  -0.085
# 1|participant_id[0bacf48c-4e2b-4783-a1cb-6415dd...  0.002  0.044  -0.089
#
#                                                     hdi_97%  mcse_mean  \
# Intercept                                            -0.424      0.003
# shown_proof                                           0.250      0.005
# C(rank)[2]                                            0.430      0.004
# C(rank)[3]                                            0.244      0.004
# C(rank)[4]                                           -0.113      0.004
# C(rank)[5]                                           -0.172      0.004
# C(rank)[6]                                           -0.515      0.004
# C(rank)[7]                                           -0.648      0.004
# C(rank)[8]                                           -0.969      0.005
# C(rank)[9]                                           -1.263      0.004
# C(rank)[10]                                          -2.009      0.006
# shown_proof:C(rank)[2]                               -0.020      0.006
# shown_proof:C(rank)[3]                                0.358      0.006
# shown_proof:C(rank)[4]                                0.559      0.006
# shown_proof:C(rank)[5]                                0.544      0.006
# shown_proof:C(rank)[6]                                0.578      0.006
# shown_proof:C(rank)[7]                                0.643      0.006
# shown_proof:C(rank)[8]                                0.950      0.006
# shown_proof:C(rank)[9]                                0.675      0.006
# shown_proof:C(rank)[10]                               1.560      0.008
# 1|participant_id_sigma                                0.085      0.000
# 1|snapshot_id_sigma                                   0.153      0.001
# 1|post_id_sigma                                       0.188      0.002
# 1|participant_id[0121c5f9-d668-4f03-802a-5b1c84...    0.092      0.001
# 1|participant_id[024cc19c-833b-484f-b242-3c5393...    0.080      0.001
# 1|participant_id[0292643c-984a-4dd9-9635-791955...    0.090      0.001
# 1|participant_id[03255d3f-25b0-43f3-849a-54b927...    0.092      0.001
# 1|participant_id[03717b3e-2012-4b39-be0f-e97e92...    0.085      0.001
# 1|participant_id[09bac91e-de8b-42df-bb9f-b5d19c...    0.100      0.001
# 1|participant_id[0bacf48c-4e2b-4783-a1cb-6415dd...    0.087      0.001
#
#                                                     mcse_sd  ess_bulk  \
# Intercept                                             0.002    1458.0
# shown_proof                                           0.002    1182.0
# C(rank)[2]                                            0.002    1846.0
# C(rank)[3]                                            0.002    2026.0
# C(rank)[4]                                            0.003    2157.0
# C(rank)[5]                                            0.003    1990.0
# C(rank)[6]                                            0.003    2328.0
# C(rank)[7]                                            0.003    2383.0
# C(rank)[8]                                            0.003    2456.0
# C(rank)[9]                                            0.003    2927.0
# C(rank)[10]                                           0.005    3579.0
# shown_proof:C(rank)[2]                                0.003    1836.0
# shown_proof:C(rank)[3]                                0.003    1663.0
# shown_proof:C(rank)[4]                                0.003    1861.0
# shown_proof:C(rank)[5]                                0.003    1840.0
# shown_proof:C(rank)[6]                                0.003    2071.0
# shown_proof:C(rank)[7]                                0.004    2251.0
# shown_proof:C(rank)[8]                                0.004    2348.0
# shown_proof:C(rank)[9]                                0.004    2814.0
# shown_proof:C(rank)[10]                               0.007    2971.0
# 1|participant_id_sigma                                0.000    3048.0
# 1|snapshot_id_sigma                                   0.003    2211.0
# 1|post_id_sigma                                       0.001    1218.0
# 1|participant_id[0121c5f9-d668-4f03-802a-5b1c84...    0.001    6005.0
# 1|participant_id[024cc19c-833b-484f-b242-3c5393...    0.001    6621.0
# 1|participant_id[0292643c-984a-4dd9-9635-791955...    0.001    6274.0
# 1|participant_id[03255d3f-25b0-43f3-849a-54b927...    0.001    5954.0
# 1|participant_id[03717b3e-2012-4b39-be0f-e97e92...    0.001    7276.0
# 1|participant_id[09bac91e-de8b-42df-bb9f-b5d19c...    0.001    8052.0
# 1|participant_id[0bacf48c-4e2b-4783-a1cb-6415dd...    0.001    6720.0
#
#                                                     ess_tail  r_hat
# Intercept                                             2677.0    1.0
# shown_proof                                           2215.0    1.0
# C(rank)[2]                                            2930.0    1.0
# C(rank)[3]                                            2876.0    1.0
# C(rank)[4]                                            2359.0    1.0
# C(rank)[5]                                            2613.0    1.0
# C(rank)[6]                                            3203.0    1.0
# C(rank)[7]                                            2347.0    1.0
# C(rank)[8]                                            3058.0    1.0
# C(rank)[9]                                            3139.0    1.0
# C(rank)[10]                                           3102.0    1.0
# shown_proof:C(rank)[2]                                2798.0    1.0
# shown_proof:C(rank)[3]                                2679.0    1.0
# shown_proof:C(rank)[4]                                2538.0    1.0
# shown_proof:C(rank)[5]                                2857.0    1.0
# shown_proof:C(rank)[6]                                3062.0    1.0
# shown_proof:C(rank)[7]                                2825.0    1.0
# shown_proof:C(rank)[8]                                2908.0    1.0
# shown_proof:C(rank)[9]                                3075.0    1.0
# shown_proof:C(rank)[10]                               3001.0    1.0
# 1|participant_id_sigma                                1812.0    1.0
# 1|snapshot_id_sigma                                   2309.0    1.0
# 1|post_id_sigma                                       1622.0    1.0
# 1|participant_id[0121c5f9-d668-4f03-802a-5b1c84...    2996.0    1.0
# 1|participant_id[024cc19c-833b-484f-b242-3c5393...    3556.0    1.0
# 1|participant_id[0292643c-984a-4dd9-9635-791955...    3013.0    1.0
# 1|participant_id[03255d3f-25b0-43f3-849a-54b927...    3471.0    1.0
# 1|participant_id[03717b3e-2012-4b39-be0f-e97e92...    3439.0    1.0
# 1|participant_id[09bac91e-de8b-42df-bb9f-b5d19c...    3035.0    1.0
# 1|participant_id[0bacf48c-4e2b-4783-a1cb-6415dd...    2877.0    1.0

# %% [markdown]
# ---

# %%
ratings_df["rating"] = pd.Categorical(ratings_df["rating"], ordered=True)

# %%
model = bmb.Model(
    formula="rating ~ shown_proof * C(rank) + selected + (1 | participant_id) + (1 | snapshot_id) + (1 | post_id)",
    data=ratings_df.query("perception == 'relevance'").reset_index(),
    family="cumulative",
)

results = model.fit(target_accept=0.95)
# Out:
# /Users/jackie/Desktop/Files/ranking-study/.venv/lib/python3.13/site-packages/bambi/formula.py:111: UserWarning: The intercept is omitted in ordinal families
#   warnings.warn("The intercept is omitted in ordinal families")
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [rating_threshold, shown_proof, C(rank), shown_proof:C(rank), selected, 1|participant_id_sigma, 1|participant_id_offset, 1|snapshot_id_sigma, 1|snapshot_id_offset, 1|post_id_sigma, 1|post_id_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 243 seconds.

# %%
az.summary(results).head(30)
# Out:
#                           mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# shown_proof             -0.485  0.192  -0.839   -0.121      0.005    0.003
# C(rank)[2]              -0.153  0.183  -0.505    0.189      0.004    0.002
# C(rank)[3]              -0.212  0.201  -0.584    0.160      0.004    0.003
# C(rank)[4]              -0.103  0.197  -0.471    0.274      0.004    0.003
# C(rank)[5]              -0.341  0.198  -0.720    0.024      0.004    0.003
# C(rank)[6]              -0.253  0.191  -0.600    0.109      0.004    0.003
# C(rank)[7]              -0.234  0.197  -0.607    0.130      0.004    0.003
# C(rank)[8]              -0.160  0.196  -0.515    0.211      0.004    0.003
# C(rank)[9]              -0.058  0.200  -0.438    0.307      0.004    0.003
# C(rank)[10]             -0.214  0.203  -0.608    0.160      0.004    0.003
# shown_proof:C(rank)[2]   0.163  0.269  -0.332    0.665      0.006    0.003
# shown_proof:C(rank)[3]   0.537  0.293  -0.009    1.092      0.006    0.004
# shown_proof:C(rank)[4]   0.149  0.286  -0.374    0.702      0.006    0.004
# shown_proof:C(rank)[5]   0.581  0.285   0.060    1.126      0.006    0.004
# shown_proof:C(rank)[6]   0.419  0.282  -0.090    0.968      0.006    0.004
# shown_proof:C(rank)[7]   0.201  0.289  -0.324    0.757      0.006    0.004
# shown_proof:C(rank)[8]   0.371  0.290  -0.196    0.875      0.006    0.004
# shown_proof:C(rank)[9]  -0.022  0.292  -0.569    0.532      0.006    0.004
# shown_proof:C(rank)[10]  0.479  0.291  -0.091    1.022      0.006    0.004
# selected                 6.694  0.301   6.137    7.256      0.005    0.006
# rating_threshold[0]     -4.400  0.428  -5.220   -3.606      0.007    0.007
# rating_threshold[1]     -3.392  0.428  -4.149   -2.535      0.006    0.007
# rating_threshold[2]     -2.598  0.429  -3.399   -1.798      0.006    0.007
# rating_threshold[3]     -1.582  0.428  -2.398   -0.792      0.006    0.007
# rating_threshold[4]      3.497  0.437   2.715    4.341      0.006    0.008
# rating_threshold[5]      4.422  0.435   3.625    5.258      0.006    0.008
# rating_threshold[6]      5.722  0.443   4.908    6.567      0.006    0.008
# 1|participant_id_sigma   0.104  0.063   0.000    0.211      0.002    0.001
# 1|snapshot_id_sigma      3.452  1.395   1.476    6.026      0.045    0.041
# 1|post_id_sigma          0.096  0.056   0.000    0.185      0.002    0.001
#
#                          ess_bulk  ess_tail  r_hat
# shown_proof                1295.0    1964.0    1.0
# C(rank)[2]                 2225.0    2962.0    1.0
# C(rank)[3]                 2476.0    2685.0    1.0
# C(rank)[4]                 2289.0    2901.0    1.0
# C(rank)[5]                 2297.0    2687.0    1.0
# C(rank)[6]                 2272.0    2857.0    1.0
# C(rank)[7]                 2290.0    2938.0    1.0
# C(rank)[8]                 2493.0    2843.0    1.0
# C(rank)[9]                 2481.0    2952.0    1.0
# C(rank)[10]                2451.0    2760.0    1.0
# shown_proof:C(rank)[2]     1921.0    2822.0    1.0
# shown_proof:C(rank)[3]     2067.0    2711.0    1.0
# shown_proof:C(rank)[4]     2004.0    2773.0    1.0
# shown_proof:C(rank)[5]     1950.0    2242.0    1.0
# shown_proof:C(rank)[6]     1936.0    2875.0    1.0
# shown_proof:C(rank)[7]     2111.0    3128.0    1.0
# shown_proof:C(rank)[8]     2051.0    2789.0    1.0
# shown_proof:C(rank)[9]     2259.0    2951.0    1.0
# shown_proof:C(rank)[10]    2061.0    2089.0    1.0
# selected                   4668.0    2372.0    1.0
# rating_threshold[0]        4322.0    3091.0    1.0
# rating_threshold[1]        4392.0    3195.0    1.0
# rating_threshold[2]        4413.0    3018.0    1.0
# rating_threshold[3]        4468.0    3142.0    1.0
# rating_threshold[4]        5562.0    2634.0    1.0
# rating_threshold[5]        5611.0    2654.0    1.0
# rating_threshold[6]        5672.0    2672.0    1.0
# 1|participant_id_sigma     1202.0    2012.0    1.0
# 1|snapshot_id_sigma         938.0    1863.0    1.0
# 1|post_id_sigma            1249.0    2198.0    1.0

# %%
model.plot_priors()
# Out:
# Sampling: [1|participant_id_sigma, 1|post_id_sigma, 1|snapshot_id_sigma, C(rank), rating_threshold, shown_proof, shown_proof:C(rank)]
# array([[<Axes: title={'center': 'rating_threshold\n0'}>,
#         <Axes: title={'center': 'rating_threshold\n1'}>,
#         <Axes: title={'center': 'rating_threshold\n2'}>,
#         <Axes: title={'center': 'rating_threshold\n3'}>],
#        [<Axes: title={'center': 'shown_proof'}>,
#         <Axes: title={'center': 'C(rank)\n2'}>,
#         <Axes: title={'center': 'C(rank)\n3'}>,
#         <Axes: title={'center': 'C(rank)\n4'}>],
#        [<Axes: title={'center': 'C(rank)\n5'}>,
#         <Axes: title={'center': 'C(rank)\n6'}>,
#         <Axes: title={'center': 'C(rank)\n7'}>,
#         <Axes: title={'center': 'C(rank)\n8'}>],
#        [<Axes: title={'center': 'C(rank)\n9'}>,
#         <Axes: title={'center': 'C(rank)\n10'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n2'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n3'}>],
#        [<Axes: title={'center': 'shown_proof:C(rank)\n4'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n5'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n6'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n7'}>],
#        [<Axes: title={'center': 'shown_proof:C(rank)\n8'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n9'}>,
#         <Axes: title={'center': 'shown_proof:C(rank)\n10'}>,
#         <Axes: title={'center': '1|participant_id_sigma'}>],
#        [<Axes: title={'center': '1|snapshot_id_sigma'}>,
#         <Axes: title={'center': '1|post_id_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
az.plot_trace(results)
# Out:
# array([[<Axes: title={'center': 'shown_proof'}>,
#         <Axes: title={'center': 'shown_proof'}>],
#        [<Axes: title={'center': 'rank'}>,
#         <Axes: title={'center': 'rank'}>],
#        [<Axes: title={'center': 'shown_proof:rank'}>,
#         <Axes: title={'center': 'shown_proof:rank'}>],
#        [<Axes: title={'center': 'rating_threshold'}>,
#         <Axes: title={'center': 'rating_threshold'}>],
#        [<Axes: title={'center': '1|participant_id_sigma'}>,
#         <Axes: title={'center': '1|participant_id_sigma'}>],
#        [<Axes: title={'center': '1|snapshot_id_sigma'}>,
#         <Axes: title={'center': '1|snapshot_id_sigma'}>],
#        [<Axes: title={'center': '1|post_id_sigma'}>,
#         <Axes: title={'center': '1|post_id_sigma'}>],
#        [<Axes: title={'center': '1|participant_id'}>,
#         <Axes: title={'center': '1|participant_id'}>],
#        [<Axes: title={'center': '1|snapshot_id'}>,
#         <Axes: title={'center': '1|snapshot_id'}>],
#        [<Axes: title={'center': '1|post_id'}>,
#         <Axes: title={'center': '1|post_id'}>]], dtype=object)
